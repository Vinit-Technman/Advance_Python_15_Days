# %% [markdown]
# gedax80765@avastu.com

# %%
# !pip install quandl
# Out:
# Collecting quandl
#   Obtaining dependency information for quandl from https://files.pythonhosted.org/packages/c9/cd/54ab3484243431e02dabab1254ffde296c005e0d11346536e5e02ce6c828/Quandl-3.7.0-py2.py3-none-any.whl.metadata
#   Downloading Quandl-3.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pandas>=0.14 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from quandl) (2.2.2)
# Requirement already satisfied: numpy>=1.8 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from quandl) (1.26.4)
# Requirement already satisfied: requests>=2.7.0 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from quandl) (2.31.0)
# Collecting inflection>=0.3.1 (from quandl)
#   Obtaining dependency information for inflection>=0.3.1 from https://files.pythonhosted.org/packages/59/91/aa6bde563e0085a02a435aa99b49ef75b0a4b062635e606dab23ce18d720/inflection-0.5.1-py2.py3-none-any.whl.metadata
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from quandl) (2.9.0.post0)
# Requirement already satisfied: six in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from quandl) (1.16.0)
# Collecting more-itertools (from quandl)
#   Obtaining dependency information for more-itertools from https://files.pythonhosted.org/packages/50/e2/8e10e465ee3987bb7c9ab69efb91d867d93959095f4807db102d07995d94/more_itertools-10.2.0-py3-none-any.whl.metadata
#   Downloading more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.14->quandl) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.14->quandl) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.7.0->quandl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.7.0->quandl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.7.0->quandl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vinit\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.7.0->quandl) (2024.2.2)
# Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------------------- 57.0/57.0 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: more-itertools, inflection, quandl
# Successfully installed inflection-0.5.1 more-itertools-10.2.0 quandl-3.7.0
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Read time series data from a CSV file using Pandas

# %%
# # S7-rFCyn3Z3jY2PyPxNo
# # quandl for financial data
# import quandl
# # pandas for data manipulation
# import pandas as pd
# quandl.ApiConfig.api_key = 'S7-rFCyn3Z3jY2PyPxNo'
# # Retrieve TSLA data from Quandl
# tesla = quandl.get('WIKI/TSLA')
# # Retrieve the GM data from Quandl
# gm = quandl.get('WIKI/GM')
# gm.head(5)


import pandas as pd
df=pd.read_csv('Electric_Production.csv')

df
# Out:
#           DATE  IPG2211A2N
# 0     1/1/1985     72.5052
# 1     2/1/1985     70.6720
# 2     3/1/1985     62.4502
# 3     4/1/1985     57.4714
# 4     5/1/1985     55.3151
# ..         ...         ...
# 392   9/1/2017     98.6154
# 393  10/1/2017     93.6137
# 394  11/1/2017     97.3359
# 395  12/1/2017    114.7212
# 396   1/1/2018    129.4048
#
# [397 rows x 2 columns]

# %% [markdown]
# Plot time series data using Matplotlib

# %%
import matplotlib.pyplot as plt
df=df.iloc[:20]
plt.figure(1,figsize=(20,6))
plt.plot(df['DATE'],df['IPG2211A2N'])
plt.show()

# %% [markdown]
# Implement a program that calculates and plots the rolling
# mean of a time series using Pandas

# %%
# S7-rFCyn3Z3jY2PyPxNo
df=pd.read_csv("Tesla_Stock.csv",index_col='Date')
# df['Close']=df['Close'].to_frame()
# sum(df['Close'].isna())

# for 30 days interval
# first 29 will be NaN
df['Rolling Mean 30']=df['Close'].rolling(30).mean()

# for 200 days interval
# first 199 will be NaN
df['Rolling Mean 200']=df['Close'].rolling(200).mean()

# plt.plot(df['Rolling Mean 30'],df['Rolling Mean 200'])
df[['Close','Rolling Mean 30','Rolling Mean 200']].plot(label="Tesla Stock",figsize=(12,5))
# plt.show()
# df
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
#  Write a Python program that uses Pandas to resample
# time series data to a lower frequency (e.g., from daily to
# weekly
